# %%
# !pip install transformers
# !pip install datasets
# !pip install evaluate
# !pip show transformers
# !pip show accelerate
# !pip install accelerate -U
# !pip install transformers[torch]
# !pip install evaluate
# Out:
# Requirement already satisfied: transformers in /home/baran/miniconda3/lib/python3.12/site-packages (4.46.0)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: datasets in /home/baran/miniconda3/lib/python3.12/site-packages (2.19.1)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: multiprocess in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.25.1)
# Requirement already satisfied: packaging in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# Name: transformers
# Version: 4.46.0
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /home/baran/miniconda3/lib/python3.12/site-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by:
# Name: accelerate
# Version: 1.0.1
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /home/baran/miniconda3/lib/python3.12/site-packages
# Requires: huggingface-hub, numpy, packaging, psutil, pyyaml, safetensors, torch
# Required-by:
# Requirement already satisfied: accelerate in /home/baran/miniconda3/lib/python3.12/site-packages (1.0.1)
# Collecting accelerate
#   Downloading accelerate-1.2.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (5.8.0)
# Requirement already satisfied: pyyaml in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.3.1)
# Requirement already satisfied: requests in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (3.1.0)
# Requirement already satisfied: setuptools in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Downloading accelerate-1.2.0-py3-none-any.whl (336 kB)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.0.1
#     Uninstalling accelerate-1.0.1:
#       Successfully uninstalled accelerate-1.0.1
# Successfully installed accelerate-1.2.0
# Requirement already satisfied: transformers[torch] in /home/baran/miniconda3/lib/python3.12/site-packages (4.46.0)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (2024.9.11)
# Requirement already satisfied: requests in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: accelerate>=0.26.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (1.2.0)
# Requirement already satisfied: torch in /home/baran/miniconda3/lib/python3.12/site-packages (from transformers[torch]) (2.5.1)
# Requirement already satisfied: psutil in /home/baran/miniconda3/lib/python3.12/site-packages (from accelerate>=0.26.0->transformers[torch]) (5.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (4.12.2)
# Requirement already satisfied: networkx in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (3.1.0)
# Requirement already satisfied: setuptools in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from torch->transformers[torch]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch->transformers[torch]) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers[torch]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->transformers[torch]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: evaluate in /home/baran/miniconda3/lib/python3.12/site-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: multiprocess in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (0.25.1)
# Requirement already satisfied: packaging in /home/baran/miniconda3/lib/python3.12/site-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/baran/miniconda3/lib/python3.12/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/baran/miniconda3/lib/python3.12/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/baran/miniconda3/lib/python3.12/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.11.0)
# Requirement already satisfied: six>=1.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)

# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.5-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging in /home/baran/miniconda3/lib/python3.12/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /home/baran/miniconda3/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /home/baran/miniconda3/lib/python3.12/site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/baran/miniconda3/lib/python3.12/site-packages (from requests->kagglehub) (2024.8.30)
# Downloading kagglehub-0.3.5-py3-none-any.whl (44 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.5

# %%
from transformers import SegformerForSemanticSegmentation
from transformers import SegformerFeatureExtractor
from transformers import TrainingArguments, Trainer
from torchvision.transforms import ColorJitter, Resize, Compose, PILToTensor
from torchvision.transforms.functional import to_tensor

import torch
from torch import nn
import evaluate
import datasets
from datasets import Dataset, Features
import numpy as np

import os.path as op
from glob import glob
from pathlib import Path
from PIL import Image
from tqdm.auto import tqdm
import os
import json

import cv2

import kagglehub

# Download latest version
path = kagglehub.dataset_download("humansintheloop/teeth-segmentation-on-dental-x-ray-images")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/humansintheloop/teeth-segmentation-on-dental-x-ray-images?dataset_version_number=1...
# 100%|██████████| 4.14G/4.14G [09:29<00:00, 7.81MB/s]
# Extracting files...
# Path to dataset files: /home/baran/.cache/kagglehub/datasets/humansintheloop/teeth-segmentation-on-dental-x-ray-images/versions/1
